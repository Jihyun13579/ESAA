# %% [markdown]
# <a href="https://colab.research.google.com/github/Jihyun13579/ESAA/blob/main/1106(%EC%9B%94)_%EA%B3%BC%EC%A0%9C_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EC%99%84%EB%B2%BD%EA%B0%80%EC%9D%B4%EB%93%9C_ch9_1~4_pg_562~579_%ED%95%84%EC%82%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1106(월) 과제_파이썬 머신러닝 완벽가이드 ch9. 1 ~ 4 pg. 562 ~ 579 필사
# ###2129014 박지현

# %% [markdown]
# # CH09. 추천 시스템

# %% [markdown]
# ## CH09.01. 추천 시스템의 개요와 배경

# %% [markdown]
# ### 추천 시스템의 개요
#  추천 시스템(Recommendations)의 전성시대 : 발전하는 추천 엔진으로 인해 고객을 사이트에 오래 머무르게 하고, 많은 수익을 올릴 수 있게 됨
# - ex. 유튜브, 애플 뮤직 / 전자상거래 업체 : 몇 개의 사용자가 이용한 콘텐츠를 바탕으로 그와 유사하거나 연관된 콘텐츠가 줄줄이 추천됨 > 추천 콘텐츠 대부분이 개인적 취향을 정확히 이해하고 추천한 것 같은 인상
#
# 추천 시스템의 진정한 묘미 : 사용자 자신도 좋아하는지 몰랐던 취향을 시스템이 발견, 콘텐츠 추천 > 해당 사이트 더 강하게 신뢰, 더 많은 추천 콘텐츠 선택 > 더 많은 데이터가 추천 시스템에 축적되면서 추천이 더욱 정확해지고 다양한 결과를 얻르 수 있는 좋은 선순환 시스템 구축 가능

# %% [markdown]
# ### 온라인 스토어의 필수 요소, 추천 시스템
# 추천 시스템 : 특히 온라인에서 그 진가를 발휘함
#
# 한정된 시간이라는 제약을 가진 상황에서 너무 많은 상품과 콘텐츠: 사용자에게 압박감을 줌 > 추천 시스템이 이 상황 타개 가능 > 온라인 스토어에서 추천 시스템은 필수 구성 요소
#
# - 온라인 스토어 : 많은 양의 고객과 상품 관련 데이터 보유 > 상품 추천에 사용됨
#  - ex. 사용자는 어떤 상품을 구매했는가?
#
#
#  ![스크린샷 2023-11-10 161333.png](data:image/png;base64,...)

# %% [markdown]
# ### 추천 시스템의 유형
#
# 크게 콘텐츠 기반 필터링(Content based filtering) 방식 / 협업 필터링(Collaborative Filtering) 방식으로 나뉨
#  - 협업 필터링(Collaborative Filtering) 방식 : 최근접 이웃(Nearest Neighbor) 협업 필터링과 잠재 요인(Latent Factor) 협업 필터링으로 니뉨
#
# 초창기: 콘텐츠 기반 필터링 or 최근접 이웃 기반 협업 필터링 주로 사용 > 넷플릭스 추천 시스템 경연 대회에서 행렬 분해(Matrix Factorization)기법 이용한 잠재 요인 협업 필터링 우승 > 현대 대부분의 온라인 스토어에서 잠재 요인 협업 필터링 기반의 추천 시스템 적용 / 서비스하는 아이템의 특성에 따라 콘텐츠 기반 필터링 or 최근접 이웃 기반 협업 필터링(ex. 아마존) 유지하는 사이트도 많음 / 개인화 특성 강화 위해 콘텐스 기반 + 협업 기반 하이브리드 형식으로 적절히 결합해 사용하는 경우 증가

# %% [markdown]
# ## CH09.02. 콘텐츠 기반 필터링 추천 시스템
# : 사용자가 특정한 아이템을 매우 선호하는 경우, 그 아이템과 비슷한 콘텐츠를 가진 다른 아이템을 추천하는 방식
#  - 사용자가 특정 영화에 높은 평점을 줬다면, 그 영화의 장르, 출연 배우, 감독, 영화 키워드 등의 콘텐츠와 유사한 다른 영화 추천해주는 방식
#  ex. '켄텍트' 8점 / '프로메테우스' 9점 > 사용자가 선호하는 감독, 장르, 키워드 등의 콘텐츠를 다양하게 포함하고 있는 영화 '블레이드 러너 2049' 콘텐츠 기반 필터링 추천 시스템에 의해서 추천될 수 있음
#
#
#  ![스크린샷 2023-11-10 162340.png](data:image/png;base64,...)

# %% [markdown]
# ## CH09.03. 최근접 이웃 협업 필터링
#
# **협업 필터링(Collaborative Filtering)** : 사용자가 아이템에 매긴 평점 정보나 상품 구매 이력과 같은 사용자 행동 양식(User Behavior)만을 기반으로 추천을 수행하는 것
#  - cf. 취향이 비슷한 친구들에게 물어보는 것

# %% [markdown]
# ## CH09.04. 잠재 요인 협업 필터링

# %%
import numpy as np
# 원본 행렬 R 생성, 분해 행렬 P와 Q 초기화, 잠재 요인 차원 K는 3으로 결정.
R = np.array([[4, np.NaN, np.NaN, 2, np.NaN],
              [np.NaN, 5, np.NaN, 3, 1],
              [np.NaN, np.NaN, 3, 4, 4],
              [5, 2, 1, 2, np.NaN]])
num_users, num_items = R.shape
K = 3

# P와 Q 행렬의 크기를 지정하고 정규 분포를 가진 임의의 값으로 입력합니다.
np.random.seed(1)
P = np.random.normal(scale=1./K, size=(num_users, K))
Q = np.random.normal(scale=1./K, size=(num_items, K))

# %%
from sklearn.metrics import mean_squared_error

def get_rmse(R, P, Q, non_zeros):
  error = 0
  # 두 개의 분해된 행렬 P와 Q.T의 내적으로 예측 R 행렬 생성
  full_pred_matrix = np.dot(P, Q.T)

  # 실제 R 행렬에서 널이 아닌 값의 위치 인덱스 추출해 실제 R 행렬과 예측 행렬의 RMSE 추출
  x_non_zero_ind = [non_zero[0] for non_zero in non_zeros]
  y_non_zero_ind = [non_zero[1] for non_zero in non_zeros]
  R_non_zeros = R[x_non_zero_ind, y_non_zero_ind]
  full_pred_matrix_non_zeros = full_pred_matrix[x_non_zero_ind, y_non_zero_ind]
  mse = mean_squared_error(R_non_zeros, full_pred_matrix_non_zeros)
  rmse = np.sqrt(mse)

  return rmse

# %%
# R > 0인 행 위치, 열 위치, 값을 non_zeros 리스트에 저장.
non_zeros = [ (i, j, R[i, j]) for i in range(num_users) for j in range(num_items) if R[i, j] > 0 ]

steps = 1000
learning_rate = 0.01
r_lambda = 0.01

# SGD 기법으로 P와 Q 매트릭스를 계속 업데이트.
for step in range(steps):
  for i, j, r in non_zeros:
    # 실제 값과 예측 값의 차이인 오류 값 구함
    eij = r - np.dot(P[i, :], Q[j, :].T)
    # Regularization을 반영한 SGD 업데이트 공식 적용
    P[i, :] = P[i, :] + learning_rate * (eij * Q[j, :] - r_lambda * P[i, :])
    Q[j, :] = Q[j, :] + learning_rate * (eij * P[i, :] - r_lambda * Q[j, :])

  rmse = get_rmse(R, P, Q, non_zeros)
  if (step % 50) == 0:
    print('### iteration step:', step, 'rmse:', rmse)
# Out:
# ### iteration step: 0 rmse: 3.2388050277987723
# ### iteration step: 50 rmse: 0.4876723101369648
# ### iteration step: 100 rmse: 0.1564340384819247
# ### iteration step: 150 rmse: 0.07455141311978046
# ### iteration step: 200 rmse: 0.04325226798579314
# ### iteration step: 250 rmse: 0.029248328780878973
# ### iteration step: 300 rmse: 0.022621116143829466
# ### iteration step: 350 rmse: 0.019493636196525135
# ### iteration step: 400 rmse: 0.018022719092132704
# ### iteration step: 450 rmse: 0.01731968595344266
# ### iteration step: 500 rmse: 0.016973657887570753
# ### iteration step: 550 rmse: 0.016796804595895633
# ### iteration step: 600 rmse: 0.01670132290188466
# ### iteration step: 650 rmse: 0.01664473691247669
# ### iteration step: 700 rmse: 0.016605910068210026
# ### iteration step: 750 rmse: 0.016574200475705
# ### iteration step: 800 rmse: 0.01654431582921597
# ### iteration step: 850 rmse: 0.01651375177473524
# ### iteration step: 900 rmse: 0.01648146573819501
# ...

# %% [markdown]
# 3. 분해된 P와 Q 함수를 P*Q.T로 예측 행렬 만들어서 출력해보기

# %%
pred_matrix = np.dot(P, Q.T)
print('예측 행렬:\n', np.round(pred_matrix, 3))
# Out:
# 예측 행렬:
#  [[3.991 0.897 1.306 2.002 1.663]
#  [6.696 4.978 0.979 2.981 1.003]
#  [6.677 0.391 2.987 3.977 3.986]
#  [4.968 2.005 1.006 2.017 1.14 ]]
